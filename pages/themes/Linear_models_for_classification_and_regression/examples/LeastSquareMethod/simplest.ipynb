# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,6)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = 2*x + 1
y
# Out:
# array([ 3,  5,  7,  9, 11])

# %%
fig, ax = plt.subplots()
ax.grid()

# ax.spines['bottom'].set_position('center')
# ax.spines['left'].set_position('center')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xticks(np.arange(0, 6, 1))
ax.set_yticks(np.arange(0, 12, 1))

ax.set_xlim(0)
ax.set_ylim(0)

ax.plot(x,y)

# %% [markdown]
# <iframe src="https://www.desmos.com/calculator/exwg6bb5lb?embed" width="500" height="500" style="border: 1px solid #ccc" frameborder=0></iframe>
# [View Graph]([https://](https://www.desmos.com/calculator/qbvkflgcan))
